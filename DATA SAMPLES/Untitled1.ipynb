# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('LOOntology_InitialDataLoad - Data Structures (1).xlsx', sheet_name = None)

# %%
df = pd.concat(pd.read_excel('LOOntology_InitialDataLoad - Data Structures (1).xlsx', sheet_name=None), ignore_index=True)
sheet_to_df_map = pd.read_excel('LOOntology_InitialDataLoad - Data Structures (1).xlsx', sheet_name=None)

# %%
pd.read_excel('LOOntology_InitialDataLoad - Data Structures (1).xlsx', sheet_name = None) 
pd.concat(pd.read_excel('LOOntology_InitialDataLoad - Data Structures (1).xlsx', sheet_name=None), ignore_index=True)
# Out:
#                              Topic  LMID  \
# 0    Data Structures- Introduction    M1
# 1    Data Structures- Introduction    M2
# 2    Data Structures- Introduction    M3
# 3    Data Structures- Introduction    M4
# 4    Data Structures- Introduction    M5
# ..                             ...   ...
# 308                      Recursion  M309
# 309                      Recursion  M310
# 310                      Recursion  M311
# 311                      Recursion  M312
# 312                      Recursion  M313
#
#                                               Title    Structure  \
# 0                                    Data Structure       Linear
# 1                   Introduction to Data Structures       Linear
# 2    Introduction to Data Structures and Algorithms    Hierarchy
# 3                   Introduction to Data Structures    Hierarchy
# 4                                    Data Structure    Hierarchy
# ..                                              ...          ...
# ...

# %%
    data=pd.ExcelFile('LOOntology_InitialDataLoad - Data Structures (1).xlsx')

# %%
data

# %%
data1=data.sheet_names

# %%
data1
# Out:
# ['DS-Intro',
#  'DS-Array',
#  'DS-Stack ',
#  'DS-StackApplications',
#  'DS-Queue',
#  'DS-LinkedList',
#  'DS- tree',
#  'DS- Graphs',
#  'DS-Graph- Dijkstra',
#  'DS-Graph-Prims',
#  'DS-Graph-Kruskals',
#  'DS-Bubble Sort',
#  'DS- Insertion Sort',
#  'DS-Selection Sort',
#  'DS- Merge Sort',
#  'DS- Shell Sort',
#  'DS- Quick Sort',
#  'DS-Linear Search',
#  'DS-BinarySearch',
#  'DS- Hashing',
#  'DS- Recursion']

# %%
data12
# Out:
#                             Topic  LMID  \
# 0   Data Structures- Introduction    M1
# 1   Data Structures- Introduction    M2
# 2   Data Structures- Introduction    M3
# 3   Data Structures- Introduction    M4
# 4   Data Structures- Introduction    M5
# ..                            ...   ...
# 10                      Recursion  M309
# 11                      Recursion  M310
# 12                      Recursion  M311
# 13                      Recursion  M312
# 14                      Recursion  M313
#
#                                              Title    Structure  \
# 0                                   Data Structure       Linear
# 1                  Introduction to Data Structures       Linear
# 2   Introduction to Data Structures and Algorithms    Hierarchy
# 3                  Introduction to Data Structures    Hierarchy
# 4                                   Data Structure    Hierarchy
# ..                                             ...          ...
# ...

# %%
df_records = data12.to_dict('records')

# %%
excel_df=pd.concat(pd.read_excel('LOOntology_InitialDataLoad - Data Structures (1).xlsx', sheet_name=None), ignore_index=True)
df_records = excel_df.to_dict('records')
len(df_records)
# Out:
# 313

# %%
y()
# Out:
# [10, 12, 3, 10, 12, 3]

# %%
[10,12,3]*2
# Out:
# [10, 12, 3, 10, 12, 3]
