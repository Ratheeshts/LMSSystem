# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel("data.xlsx")

# %%
df
# Out:
#      Sid  Name  Age Gender Qualification                        Branch  \
# 0      1    L1   18      M            HS     Mathematics with Computer
# 1      2    L2   19      M            HS                       Science
# 2      3    L3   17      M            HS     Mathematics with Computer
# 3      4    L4   19      M            HS                       Science
# 4      5    L5   18      M            HS     Mathematics with Computer
# ..   ...   ...  ...    ...           ...                           ...
# 295  296  L296   22      F      Graduate  BTech Information Technology
# 296  297  L297   23      F      Graduate        BTech Computer Science
# 297  298  L298   22      F      Graduate          BSc Computer Science
# 298  299  L299   22      F      Graduate  BTech Information Technology
# 299  300  L300   23      F      Graduate        BTech Computer Science
#
#     BackgroundKnowledge
# 0          Intermediate
# 1          Intermediate
# 2                Expert
# ...

# %%
for r in df.itertuples():
    print(r)
# Out:
# Pandas(Index=0, Sid=1, Name='L1', Age=18, Gender='M', Qualification='HS', Branch='Mathematics with Computer', BackgroundKnowledge='Intermediate')
# Pandas(Index=1, Sid=2, Name='L2', Age=19, Gender='M', Qualification='HS', Branch='Science', BackgroundKnowledge='Intermediate')
# Pandas(Index=2, Sid=3, Name='L3', Age=17, Gender='M', Qualification='HS', Branch='Mathematics with Computer', BackgroundKnowledge='Expert')
# Pandas(Index=3, Sid=4, Name='L4', Age=19, Gender='M', Qualification='HS', Branch='Science', BackgroundKnowledge='Basic')
# Pandas(Index=4, Sid=5, Name='L5', Age=18, Gender='M', Qualification='HS', Branch='Mathematics with Computer', BackgroundKnowledge='Intermediate')
# Pandas(Index=5, Sid=6, Name='L6', Age=18, Gender='M', Qualification='HS', Branch='Mathematics with Computer', BackgroundKnowledge='Expert')
# Pandas(Index=6, Sid=7, Name='L7', Age=17, Gender='M', Qualification='HS', Branch='Science', BackgroundKnowledge='Basic')
# ...

# %%
df.to_numpy()
# Out:
# array([[1, 'L1', 18, ..., 'HS', 'Mathematics with Computer',
#         'Intermediate'],
#        [2, 'L2', 19, ..., 'HS', 'Science', 'Intermediate'],
#        [3, 'L3', 17, ..., 'HS', 'Mathematics with Computer', 'Expert'],
#        ...,
#        [298, 'L298', 22, ..., 'Graduate', 'BSc Computer Science',
#         'Intermediate'],
#        [299, 'L299', 22, ..., 'Graduate', 'BTech Information Technology',
#         'Basic'],
#        [300, 'L300', 23, ..., 'Graduate', 'BTech Computer Science',
#         'Basic']], dtype=object)

# %%
df1 = pd.DataFrame()

df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1['name']=['raju','thom','krishnada']

# %%
df1
# Out:
#         name
# 0       raju
# 1       thom
# 2  krishnada

# %%
data={'raju':'dad','thgrom':'sdds','krishnada':'sdds'}

# %%
df.head(10)
# Out:
#    Sid Name  Age Gender Qualification                     Branch  \
# 0    1   L1   18      M            HS  Mathematics with Computer
# 1    2   L2   19      M            HS                    Science
# 2    3   L3   17      M            HS  Mathematics with Computer
# 3    4   L4   19      M            HS                    Science
# 4    5   L5   18      M            HS  Mathematics with Computer
# 5    6   L6   18      M            HS  Mathematics with Computer
# 6    7   L7   17      M            HS                    Science
# 7    8   L8   19      M            HS  Mathematics with Computer
# 8    9   L9   18      M            HS  Mathematics with Computer
# 9   10  L10   18      M            HS                    Science
#
#   BackgroundKnowledge
# 0        Intermediate
# 1        Intermediate
# 2              Expert
# 3               Basic
# 4        Intermediate
# 5              Expert
# 6               Basic
# 7        Intermediate
# 8              Expert
# ...

# %%
df.

# %%
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Height': [5.1, 6.2, 5.1, 5.2], 
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}

# %%
df1
# Out:
#      Name  Height Qualification
# 0     Jai     5.1           Msc
# 1  Princi     6.2            MA
# 2  Gaurav     5.1           Msc
# 3    Anuj     5.2           Msc
